# %% [markdown]
# <a href="https://colab.research.google.com/github/PraptiKrishnapurkar/Python-prac/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=15
a+b
# Out:
# 25

# %%
student_name="Prapti"
student_age=19
percentage="82%"
roll=222
print(f"Name of the student is {student_name} and age is {student_age} and percentage are {percentage} and roll no is {roll}")
print(f"name :{student_name}\nage :{student_age}\npercentage: {percentage}\nroll:{roll}")
# Out:
# Name of the student is Prapti and age is 19 and percentage are 82% and roll no is 222
# name :Prapti
# age :19
# percentage: 82%
# roll:222

# %%
print('Prapti here')
# Out:
# Prapti here

# %%
print('Welcome back')
# Out:
# Welcome back

# %%
print(""" hellooooooo
hiiiii """)
# Out:
#  hellooooooo
# hiiiii

# %%
print(''' guyss hello ''')
# Out:
#  guyss hello

# %%
n1=input("enter the value of n1")
n2=input("enter the value of n2")
print(f"multiplication of {n1} and {n2} : {n1+n}")

# %%
num=1000
n1=float(num)
print("value of n1",n1)

# %%
name=input("enter the name ")
age=int(input("enter the age"))
per=float(input("enter the percentage"))
female=boolean(input("enter gender"))
salary=float(input("enter salary"))
print(f"name is {name} , \nage is {age} , \npercentage {per} , \ngender is {female}, \nsalary is {sal}")

# %%
n1=input("enter the value of n1")
n2=input("enter the value of n2")
print(f"multiplication of {n1} and {n2} : {n1*n2},\naddition of {n1} and {n2} : {n1+n2}")

# %%
n1=int(input("enter the number"))
if n1%2==0:
print("number is even")
else:
  print("number is odd")

# %%
n1=int(input("enter first number")
n2=int(input("enter second number"))

# %%
num=int("enter the number")
if num>=0:
  print("positive")
  elif num<0:
    print("negative")
    else:
      print("zero")

# %%
n1=int(input("enter the age"))
if age>=18:
  print("Your are eligible to vote")

# %%
num=int(input("Enter any no."))
if
