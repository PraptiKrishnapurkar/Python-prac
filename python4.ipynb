# %% [markdown]
# <a href="https://colab.research.google.com/github/PraptiKrishnapurkar/Python-prac/blob/main/python4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ONE DIMENSIONAL ARRAY
import numpy as np
list1=[11,22,33,44]
array1=np.array(list1)
print(list1)
print(array1)
# Out:
# [11, 22, 33, 44]
# [11 22 33 44]
